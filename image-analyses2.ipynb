# %%
import cv2
import matplotlib.pyplot as plt
image_path = "/kaggle/input/animal/Dataset/test/cat/6fcc622575e0d1fd0cf7f04c4472fd6a0f97defb7cfc3bc54e2e9a7caa9ddc438c190d7_1920.png"
image = cv2.imread(image_path)
# Display RGB image
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8, 6))
plt.imshow(rgb_image)
plt.title("RGB Image")
plt.axis("off")
plt.show()
# Display Grayscale image
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(8, 6))
plt.imshow(gray_image, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 1. Read and Display an Image

# %% [markdown]
# 2. Pixel Intensity Analysis

# %%
x, y = 50, 50
print(f"Grayscale Intensity at ({x},{y}): {gray_image[y, x]}")
print(f"RGB Intensity at ({x},{y}): {rgb_image[y, x]}")
# Out:
# Grayscale Intensity at (50,50): 192
# RGB Intensity at (50,50): [200 189 183]

# %% [markdown]
# 3. Image Conversion

# %%
import cv2
import matplotlib.pyplot as plt

# Corrected image path with file extension
image_path = "/kaggle/input/animal/Dataset/test/cat/6fcc622575e0d1fd0cf7f04c4472fd6a0f97defb7cfc3bc54e2e9a7caa9ddc438c190d7_1920.png"

# Read the image
image = cv2.imread(image_path)

# Check if image was loaded successfully
if image is None:
    print("Error: Image not found or path is incorrect.")
else:
    # Convert BGR to RGB for proper visualization
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Convert to grayscale using OpenCV
    gray_image_opencv = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Convert to grayscale manually using weighted sum (fixed line break)
    gray_manual = (
        0.2989 * rgb_image[:, :, 0] +  # Red channel
        0.5870 * rgb_image[:, :, 1] +  # Green channel
        0.1140 * rgb_image[:, :, 2]    # Blue channel
    )
    
    # Plot the images
    plt.figure(figsize=(12, 6))
    
    # OpenCV Grayscale
    plt.subplot(1, 2, 1)
    plt.imshow(gray_image_opencv, cmap="gray")
    plt.title("Grayscale (OpenCV)")
    plt.axis("off")
    
    # Manual Grayscale
    plt.subplot(1, 2, 2)
    plt.imshow(gray_manual, cmap="gray")
    plt.title("Grayscale (Manual)")
    plt.axis("off")
    
    plt.show()

# %% [markdown]
# Image Histogram

# %% [markdown]
# 5. Image Dimensions and Data Type

# %%
plt.hist(gray_image.ravel(), bins=256, range=[0, 256],
color="blue", alpha=0.7)
plt.title("Image Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()



print(f"Resolution: {image.shape[1]}x{image.shape[0]}")
print(f"Number of Channels: {image.shape[2]}")
print(f"Data Type: {image.dtype}")
# Out:
# Resolution: 1920x1920
# Number of Channels: 3
# Data Type: uint8

# %%
import cv2
import matplotlib.pyplot as plt
image_path = "/kaggle/input/animal/Dataset/test/cat/6fcc622575e0d1fd0cf7f04c4472fd6a0f97defb7cfc3bc54e2e9a7caa9ddc438c190d7_1920.png"
image = cv2.imread(image_path)
cropped_image = image[0:100, 0:100] # Crop top-left 100x100 region
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
plt.title("Cropped Image")
plt.axis("off")
plt.show()

# %%
# Half and double the dimensions
half_size = cv2.resize(image, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_LINEAR)
double_size = cv2.resize(image, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_LINEAR)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(half_size, cv2.COLOR_BGR2RGB))
plt.title("Half Size")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(double_size, cv2.COLOR_BGR2RGB))
plt.title("Double Size")
plt.axis("off")
plt.show()

# %%
# Horizontal, Vertical, and Diagonal Flips
flip_horizontal = cv2.flip(image, 1)
flip_vertical = cv2.flip(image, 0)
flip_diagonal = cv2.flip(image, -1)
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(flip_horizontal, cv2.COLOR_BGR2RGB))
plt.title("Horizontal Flip")
plt.axis("off")
plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(flip_vertical, cv2.COLOR_BGR2RGB))
plt.title("Vertical Flip")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(flip_diagonal, cv2.COLOR_BGR2RGB))
plt.title("Diagonal Flip")
plt.axis("off")
plt.show()

# %%
# Rotate by 90 degrees clockwise
rotated_90 = cv2.rotate(image, cv2.ROTATE_90_CLOCKWISE)
# Rotate by 45 degrees around center
(h, w) = image.shape[:2]
center = (w // 2, h // 2)
rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1.0)
rotated_45 = cv2.warpAffine(image, rotation_matrix, (w, h))
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(rotated_90, cv2.COLOR_BGR2RGB))
plt.title("90 Degrees Rotation")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(rotated_45, cv2.COLOR_BGR2RGB))
plt.title("45 Degrees Rotation")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Corrected image path with file extension
image_path = "/kaggle/input/animal/Dataset/test/cat/6fcc622575e0d1fd0cf7f04c4472fd6a0f97defb7cfc3bc54e2e9a7caa9ddc438c190d7_1920.png"

# Read the image
image = cv2.imread(image_path)

# Check if image was loaded successfully
if image is None:
    print("Error: Image not found or path is incorrect.")
else:
    # Set the new width
    new_width = 300
    
    # Calculate the aspect ratio and determine the new height
    aspect_ratio = image.shape[0] / image.shape[1]  # Height / Width
    new_height = int(new_width * aspect_ratio)
    
    # Resize the image while preserving aspect ratio
    resized_image = cv2.resize(
        image, (new_width, new_height), interpolation=cv2.INTER_LINEAR
    )
    
    # Display the resized image
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.title("Aspect Ratio Preserved")
    plt.axis("off")
    plt.show()

# %%
brightened_image = cv2.add(image, 50) # Increase brightness
darkened_image = cv2.subtract(image, 50) # Decrease brightness
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)

plt.imshow(cv2.cvtColor(brightened_image, cv2.COLOR_BGR2RGB))
plt.title("Brightened Image")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(darkened_image, cv2.COLOR_BGR2RGB))
plt.title("Darkened Image")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Corrected image path with file extension
image_path = "/kaggle/input/animal/Dataset/test/cat/6fcc622575e0d1fd0cf7f04c4472fd6a0f97defb7cfc3bc54e2e9a7caa9ddc438c190d7_1920.png"

# Read the image
image = cv2.imread(image_path)

# Check if image was loaded successfully
if image is None:
    print("Error: Image not found or path is incorrect.")
else:
    # Convert to grayscale using OpenCV
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Threshold the grayscale image to get a binary image
    binary1 = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)[1]
    
    # Flip the grayscale image and threshold again
    binary2 = cv2.threshold(cv2.flip(gray_image, 1), 127, 255, cv2.THRESH_BINARY)[1]
    
    # Perform bitwise operations
    bitwise_and = cv2.bitwise_and(binary1, binary2)
    bitwise_or = cv2.bitwise_or(binary1, binary2)
    bitwise_xor = cv2.bitwise_xor(binary1, binary2)
    
    # Plot the results
    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 3, 1)
    plt.imshow(bitwise_and, cmap="gray")
    plt.title("Bitwise AND")
    plt.axis("off")
    
    plt.subplot(1, 3, 2)
    plt.imshow(bitwise_or, cmap="gray")
    plt.title("Bitwise OR")
    plt.axis("off")
    
    plt.subplot(1, 3, 3)
    plt.imshow(bitwise_xor, cmap="gray")
    plt.title("Bitwise XOR")
    plt.axis("off")
    
    plt.show()
